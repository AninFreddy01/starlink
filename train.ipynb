# %%
import pandas as pd
import numpy as np

# %%
train1 = pd.read_csv('data/LP2_Telco-churn-second-2000.csv')

# %%
train1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  5600-PDUJF    Male              0      No         No       6          Yes
# 1  8292-TYSPY    Male              0      No         No      19          Yes
# 2  0567-XRHCU  Female              0     Yes        Yes      69           No
# 3  1867-BDVFH    Male              0     Yes        Yes      11          Yes
# 4  2067-QYTCF  Female              0     Yes         No      64          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0                No             DSL             No  ...               No
# 1                No             DSL             No  ...              Yes
# 2  No phone service             DSL            Yes  ...              Yes
# 3               Yes     Fiber optic             No  ...               No
# 4               Yes     Fiber optic             No  ...              Yes
#
# ...

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2043 entries, 0 to 2042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        2043 non-null   object
#  1   gender            2043 non-null   object
#  2   SeniorCitizen     2043 non-null   int64
#  3   Partner           2043 non-null   object
#  4   Dependents        2043 non-null   object
#  5   tenure            2043 non-null   int64
#  6   PhoneService      2043 non-null   object
#  7   MultipleLines     2043 non-null   object
#  8   InternetService   2043 non-null   object
#  9   OnlineSecurity    2043 non-null   object
#  10  OnlineBackup      2043 non-null   object
#  11  DeviceProtection  2043 non-null   object
#  12  TechSupport       2043 non-null   object
#  13  StreamingTV       2043 non-null   object
#  14  StreamingMovies   2043 non-null   object
#  15  Contract          2043 non-null   object
# ...

# %%
train1.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    2043.000000  2043.000000     2043.000000
# mean        0.168380    32.649046       64.712555
# std         0.374295    24.376248       29.970010
# min         0.000000     0.000000       18.550000
# 25%         0.000000     9.000000       35.825000
# 50%         0.000000    30.000000       70.250000
# 75%         0.000000    55.000000       89.625000
# max         1.000000    72.000000      118.350000

# %%
train1.duplicated().sum()
# Out:
# 0

# %%
train2 = pd.read_csv('data/Telco_churn_first_3000.csv')

# %%
train2.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female          False     True       False       1
# 1  5575-GNVDE    Male          False    False       False      34
# 2  3668-QPYBK    Male          False    False       False       2
# 3  7795-CFOCW    Male          False    False       False      45
# 4  9237-HQITU  Female          False    False       False       2
#
#    PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0         False           NaN             DSL          False  ...
# 1          True         False             DSL           True  ...
# 2          True         False             DSL           True  ...
# 3         False           NaN             DSL           True  ...
# 4          True         False     Fiber optic          False  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0            False       False       False           False  Month-to-month
# ...

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        3000 non-null   object
#  1   gender            3000 non-null   object
#  2   SeniorCitizen     3000 non-null   bool
#  3   Partner           3000 non-null   bool
#  4   Dependents        3000 non-null   bool
#  5   tenure            3000 non-null   int64
#  6   PhoneService      3000 non-null   bool
#  7   MultipleLines     2731 non-null   object
#  8   InternetService   3000 non-null   object
#  9   OnlineSecurity    2349 non-null   object
#  10  OnlineBackup      2349 non-null   object
#  11  DeviceProtection  2349 non-null   object
#  12  TechSupport       2349 non-null   object
#  13  StreamingTV       2349 non-null   object
#  14  StreamingMovies   2349 non-null   object
#  15  Contract          3000 non-null   object
# ...

# %%
train1["SeniorCitizen"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
train2["SeniorCitizen"].unique()
# Out:
# array([False,  True])

# %%
#mapping SeniorCitizen from 0,1 to False,True
train1["SeniorCitizen"] = train1["SeniorCitizen"].map({0: False, 1: True})

# %%
train1["SeniorCitizen"].unique()
# Out:
# array([False,  True])

# %%
train1["Partner"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
train1["Partner"] = train1["Partner"].map({"Yes": True, "No": False})

# %%
train1["Partner"].unique()
# Out:
# array([False,  True])

# %%
train1["Dependents"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
train1["Dependents"] = train1["Dependents"].map({"Yes": True, "No": False})
train1["Dependents"].unique()
# Out:
# array([False,  True])

# %%
train1["PaperlessBilling"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#mapping PaperlessBilling from Yes,No to True,False
train1["PaperlessBilling"] = train1["PaperlessBilling"].map({"Yes": True, "No": False})
train1["PaperlessBilling"].unique()
# Out:
# array([ True, False])

# %%
#mapping PhoneService from Yes,No to True,False
train1["PhoneService"] = train1["PhoneService"].map({"Yes": True, "No": False})
train1["PhoneService"].unique()
# Out:
# array([ True, False])

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2043 entries, 0 to 2042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        2043 non-null   object
#  1   gender            2043 non-null   object
#  2   SeniorCitizen     2043 non-null   bool
#  3   Partner           2043 non-null   bool
#  4   Dependents        2043 non-null   bool
#  5   tenure            2043 non-null   int64
#  6   PhoneService      2043 non-null   bool
#  7   MultipleLines     2043 non-null   object
#  8   InternetService   2043 non-null   object
#  9   OnlineSecurity    2043 non-null   object
#  10  OnlineBackup      2043 non-null   object
#  11  DeviceProtection  2043 non-null   object
#  12  TechSupport       2043 non-null   object
#  13  StreamingTV       2043 non-null   object
#  14  StreamingMovies   2043 non-null   object
#  15  Contract          2043 non-null   object
# ...

# %%
train1["MultipleLines"].unique()
# Out:
# array(['No', 'No phone service', 'Yes'], dtype=object)

# %%
train2["MultipleLines"].unique()
# Out:
# array([nan, False, True], dtype=object)

# %%
train1["MultipleLines"] = train1["MultipleLines"].map({"Yes": True, "No": False, "No phone service": False})
train1["MultipleLines"].unique()
# Out:
# array([False,  True])

# %%
train2.isna().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure                0
# PhoneService          0
# MultipleLines       269
# InternetService       0
# OnlineSecurity      651
# OnlineBackup        651
# DeviceProtection    651
# TechSupport         651
# StreamingTV         651
# StreamingMovies     651
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          5
# Churn                 1
# dtype: int64

# %%
def check_unique_values(df, column):
    unique_values = df[column].unique()
    print(f"Unique values in {column}: {unique_values}")

# %%
check_unique_values(train1, "InternetService")
# Out:
# Unique values in InternetService: ['DSL' 'Fiber optic' 'No']

# %%
check_unique_values(train1, "OnlineSecurity")
# Out:
# Unique values in OnlineSecurity: ['No' 'Yes' 'No internet service']

# %%
check_unique_values(train1, "OnlineBackup")
# Out:
# Unique values in OnlineBackup: ['No' 'Yes' 'No internet service']

# %%
check_unique_values(train1, "DeviceProtection")
# Out:
# Unique values in DeviceProtection: ['No' 'Yes' 'No internet service']

# %%
check_unique_values(train1, "TechSupport")
# Out:
# Unique values in TechSupport: ['Yes' 'No' 'No internet service']

# %%
check_unique_values(train1, "StreamingTV")
# Out:
# Unique values in StreamingTV: ['No' 'Yes' 'No internet service']

# %%
check_unique_values(train1, "StreamingMovies")
# Out:
# Unique values in StreamingMovies: ['No' 'Yes' 'No internet service']

# %%
#function to map service columns to True,False
def map_service_columns(df, column):
    df[column] = df[column].map({
        "Yes": True,
        "No": False,
        "No internet service": False
    })
    return df

# %%
map_service_columns(train1, "OnlineSecurity")
map_service_columns(train1, "OnlineBackup")
map_service_columns(train1, "DeviceProtection")
map_service_columns(train1, "TechSupport")
map_service_columns(train1, "StreamingTV")
map_service_columns(train1, "StreamingMovies")
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     5600-PDUJF    Male          False    False       False       6
# 1     8292-TYSPY    Male          False    False       False      19
# 2     0567-XRHCU  Female          False     True        True      69
# 3     1867-BDVFH    Male          False     True        True      11
# 4     2067-QYTCF  Female          False     True       False      64
# ...          ...     ...            ...      ...         ...     ...
# 2038  6840-RESVB    Male          False     True        True      24
# 2039  2234-XADUH  Female          False     True        True      72
# 2040  4801-JZAZL  Female          False     True        True      11
# 2041  8361-LTMKD    Male           True     True       False       4
# 2042  3186-AJIEK    Male          False    False       False      66
#
#       PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# ...

# %%
train1["StreamingMovies"].unique()
# Out:
# array([False,  True])

# %%
train1["Churn"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#mapping Churn from Yes,No to True,False
train1["Churn"] = train1["Churn"].map({"Yes": True, "No": False})
train1["Churn"].unique()
# Out:
# array([False,  True])

# %%
train1.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  5600-PDUJF    Male          False    False       False       6
# 1  8292-TYSPY    Male          False    False       False      19
# 2  0567-XRHCU  Female          False     True        True      69
# 3  1867-BDVFH    Male          False     True        True      11
# 4  2067-QYTCF  Female          False     True       False      64
#
#    PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# 0          True          False             DSL           False  ...
# 1          True          False             DSL           False  ...
# 2         False          False             DSL            True  ...
# 3          True           True     Fiber optic           False  ...
# 4          True           True     Fiber optic           False  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0             False         True        False            False
# ...

# %%
#checking if the columns of both dataframes are the same
train1.columns == train2.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
#checking the datatypes of the columns in train1
train1.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen          bool
# Partner                bool
# Dependents             bool
# tenure                int64
# PhoneService           bool
# MultipleLines          bool
# InternetService      object
# OnlineSecurity         bool
# OnlineBackup           bool
# DeviceProtection       bool
# TechSupport            bool
# StreamingTV            bool
# StreamingMovies        bool
# Contract             object
# PaperlessBilling       bool
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                  bool
# dtype: object

# %%
train2.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen          bool
# Partner                bool
# Dependents             bool
# tenure                int64
# PhoneService           bool
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling       bool
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
train2.isna().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure                0
# PhoneService          0
# MultipleLines       269
# InternetService       0
# OnlineSecurity      651
# OnlineBackup        651
# DeviceProtection    651
# TechSupport         651
# StreamingTV         651
# StreamingMovies     651
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          5
# Churn                 1
# dtype: int64

# %%
#merging both dataframes
train = pd.concat([train1, train2], ignore_index=True)

# %%
train.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  5600-PDUJF    Male          False    False       False       6
# 1  8292-TYSPY    Male          False    False       False      19
# 2  0567-XRHCU  Female          False     True        True      69
# 3  1867-BDVFH    Male          False     True        True      11
# 4  2067-QYTCF  Female          False     True       False      64
#
#    PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0          True         False             DSL          False  ...
# 1          True         False             DSL          False  ...
# 2         False         False             DSL           True  ...
# 3          True          True     Fiber optic          False  ...
# 4          True          True     Fiber optic          False  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0            False        True       False           False  Month-to-month
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5043 non-null   object
#  1   gender            5043 non-null   object
#  2   SeniorCitizen     5043 non-null   bool
#  3   Partner           5043 non-null   bool
#  4   Dependents        5043 non-null   bool
#  5   tenure            5043 non-null   int64
#  6   PhoneService      5043 non-null   bool
#  7   MultipleLines     4774 non-null   object
#  8   InternetService   5043 non-null   object
#  9   OnlineSecurity    4392 non-null   object
#  10  OnlineBackup      4392 non-null   object
#  11  DeviceProtection  4392 non-null   object
#  12  TechSupport       4392 non-null   object
#  13  StreamingTV       4392 non-null   object
#  14  StreamingMovies   4392 non-null   object
#  15  Contract          5043 non-null   object
# ...

# %%
#saving the merged dataframe to a csv file
train.to_csv('data/Telco_churn_merged.csv', index=False)

# %%
test = pd.read_csv('data/Telco-churn-last-2000.csv')

# %%
test.head()
# Out:
#    customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7613-LLQFO   Male              0      No         No      12          Yes
# 1  4568-TTZRT   Male              0      No         No       9          Yes
# 2  9513-DXHDA   Male              0      No         No      27          Yes
# 3  2640-PMGFL   Male              0      No        Yes      27          Yes
# 4  3801-HMYNL   Male              0     Yes        Yes       1          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes     Fiber optic                   No                   No
# 1            No              No  No internet service  No internet service
# 2            No             DSL                  Yes                   No
# 3           Yes     Fiber optic                   No                   No
# 4            No     Fiber optic                   No                   No
#
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        2000 non-null   object
#  1   gender            2000 non-null   object
#  2   SeniorCitizen     2000 non-null   int64
#  3   Partner           2000 non-null   object
#  4   Dependents        2000 non-null   object
#  5   tenure            2000 non-null   int64
#  6   PhoneService      2000 non-null   object
#  7   MultipleLines     2000 non-null   object
#  8   InternetService   2000 non-null   object
#  9   OnlineSecurity    2000 non-null   object
#  10  OnlineBackup      2000 non-null   object
#  11  DeviceProtection  2000 non-null   object
#  12  TechSupport       2000 non-null   object
#  13  StreamingTV       2000 non-null   object
#  14  StreamingMovies   2000 non-null   object
#  15  Contract          2000 non-null   object
# ...

# %%
map_service_columns(test, "OnlineSecurity")
map_service_columns(test, "OnlineBackup")
map_service_columns(test, "DeviceProtection")
map_service_columns(test, "TechSupport")
map_service_columns(test, "StreamingTV")
map_service_columns(test, "StreamingMovies")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7613-LLQFO    Male              0      No         No      12
# 1     4568-TTZRT    Male              0      No         No       9
# 2     9513-DXHDA    Male              0      No         No      27
# 3     2640-PMGFL    Male              0      No        Yes      27
# 4     3801-HMYNL    Male              0     Yes        Yes       1
# ...          ...     ...            ...     ...        ...     ...
# 1995  7912-SYRQT  Female              0      No         No       7
# 1996  3557-HTYWR  Female              0      No         No      47
# 1997  4816-JBHOV    Male              1      No         No       2
# 1998  8920-NAVAY    Male              1      No         No      62
# 1999  1699-TLDLZ  Female              0     Yes        Yes      16
#
#      PhoneService MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0             Yes           Yes     Fiber optic           False         False
# ...

# %%
#mapping Churn from Yes,No to True,False
def map_columns(df, column):
    df[column] = df[column].map({
        "Yes": True,
        "No": False,
    })
    return df

# %%
map_columns(test, "Partner")
map_columns(test, "Dependents")
map_columns(test, "PaperlessBilling")
map_columns(test, "PhoneService")
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7613-LLQFO    Male              0    False       False      12
# 1     4568-TTZRT    Male              0    False       False       9
# 2     9513-DXHDA    Male              0    False       False      27
# 3     2640-PMGFL    Male              0    False        True      27
# 4     3801-HMYNL    Male              0     True        True       1
# ...          ...     ...            ...      ...         ...     ...
# 1995  7912-SYRQT  Female              0    False       False       7
# 1996  3557-HTYWR  Female              0    False       False      47
# 1997  4816-JBHOV    Male              1    False       False       2
# 1998  8920-NAVAY    Male              1    False       False      62
# 1999  1699-TLDLZ  Female              0     True        True      16
#
#       PhoneService MultipleLines InternetService  OnlineSecurity  \
# 0             True           Yes     Fiber optic           False
# ...

# %%
test["MultipleLines"] = test["MultipleLines"].map({
    "Yes": True,
    "No": False,
    "No phone service": False
})
test["MultipleLines"].unique()
# Out:
# array([ True, False])

# %%
test["SeniorCitizen"] = test["SeniorCitizen"].map({0: False, 1: True})
test["SeniorCitizen"].unique()
# Out:
# array([False,  True])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        2000 non-null   object
#  1   gender            2000 non-null   object
#  2   SeniorCitizen     2000 non-null   bool
#  3   Partner           2000 non-null   bool
#  4   Dependents        2000 non-null   bool
#  5   tenure            2000 non-null   int64
#  6   PhoneService      2000 non-null   bool
#  7   MultipleLines     2000 non-null   bool
#  8   InternetService   2000 non-null   object
#  9   OnlineSecurity    2000 non-null   bool
#  10  OnlineBackup      2000 non-null   bool
#  11  DeviceProtection  2000 non-null   bool
#  12  TechSupport       2000 non-null   bool
#  13  StreamingTV       2000 non-null   bool
#  14  StreamingMovies   2000 non-null   bool
#  15  Contract          2000 non-null   object
#  16  PaperlessBilling  2000 non-null   bool
# ...

# %%
#saveing the test dataframe to a csv file
test.to_csv('data/Telco_churn_test.csv', index=False)
